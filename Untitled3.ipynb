# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('DC_Properties_trimmed.csv')

# %%
df.head()
# Out:
#    BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM   AYB  \
# 0       4          0      Warm Cool  Y          2      8      4  1910
# 1       3          1  Hot Water Rad  Y          2      9      5  1910
# 2       3          1  Hot Water Rad  Y          2      8      5  1900
# 3       3          1  Hot Water Rad  Y          2      8      4  1906
# 4       3          1      Warm Cool  Y          2      7      3  1908
#
#    YR_RMDL   EYB  ...  LONGITUDE ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD  \
# 0     1988  1972  ... -77.040832      Old City 2    040 D Old City 2
# 1     2009  1984  ... -77.040678      Old City 2    040 D Old City 2
# 2     2003  1984  ... -77.040629      Old City 2    040 D Old City 2
# 3     2011  1972  ... -77.040129      Old City 2    040 D Old City 2
# 4     2008  1967  ... -77.039903      Old City 2    040 D Old City 2
#
#   CENSUS_TRACT  CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28900 entries, 0 to 28899
# Data columns (total 46 columns):
# BATHRM                28900 non-null int64
# HF_BATHRM             28900 non-null int64
# HEAT                  28900 non-null object
# AC                    28900 non-null object
# NUM_UNITS             28900 non-null int64
# ROOMS                 28900 non-null int64
# BEDRM                 28900 non-null int64
# AYB                   28900 non-null int64
# YR_RMDL               28900 non-null int64
# EYB                   28900 non-null int64
# STORIES               28900 non-null float64
# SALEDATE              28900 non-null object
# PRICE                 28900 non-null int64
# QUALIFIED             28900 non-null object
# SALE_NUM              28900 non-null int64
# GBA                   28900 non-null int64
# BLDG_NUM              28900 non-null int64
# STYLE                 28900 non-null object
# STRUCT                28900 non-null object
# ...

# %%
df.describe()
# Out:
#              BATHRM     HF_BATHRM     NUM_UNITS         ROOMS         BEDRM  \
# count  28900.000000  28900.000000  28900.000000  28900.000000  28900.000000
# mean       2.333806      0.662007      1.261246      7.502872      3.482318
# std        1.038695      0.588201      0.635730      2.319767      1.160678
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        2.000000      0.000000      1.000000      6.000000      3.000000
# 50%        2.000000      1.000000      1.000000      7.000000      3.000000
# 75%        3.000000      1.000000      1.000000      8.000000      4.000000
# max       11.000000     11.000000      6.000000     31.000000     20.000000
#
#                 AYB       YR_RMDL           EYB       STORIES         PRICE  \
# count  28900.000000  28900.000000  28900.000000  28900.000000  2.890000e+04
# mean    1922.556574   2004.259273   1969.125433      2.165972  6.549323e+05
# ...

# %%
df.columns
# Out:
# Index(['BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS', 'BEDRM',
#        'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE', 'QUALIFIED',
#        'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE', 'CNDTN',
#        'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES', 'USECODE',
#        'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'FULLADDRESS', 'CITY',
#        'STATE', 'ZIPCODE', 'NATIONALGRID', 'LATITUDE', 'LONGITUDE',
#        'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD', 'CENSUS_TRACT', 'CENSUS_BLOCK',
#        'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
missing_val=sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis',xticklabels=True)

# %%
sns.boxplot(y= df['PRICE'])

# %%
df['HEAT'].unique()
# Out:
# array(['Warm Cool', 'Hot Water Rad', 'Forced Air', 'Elec Base Brd',
#        'Ht Pump', 'Wall Furnace', 'Electric Rad', 'Water Base Brd',
#        'No Data', 'Ind Unit', 'Evp Cool', 'Air Exchng', 'Air-Oil',
#        'Gravity Furnac'], dtype=object)

# %%
df['AC'].unique()
# Out:
# array(['Y', 'N', '0'], dtype=object)

# %%
#df['STYLE'].unique()
# Out:
# array(['3 Story', '2 Story', '4 Story', '3.5 Story Fin', '1 Story',
#        '2.5 Story Fin', '1.5 Story Fin', '2.5 Story Unfin', 'Default',
#        '3.5 Story Unfin', '1.5 Story Unfin', 'Split Level', 'Split Foyer',
#        'Vacant', '4.5 Story Fin', 'Bi-Level', '4.5 Story Unfin'],
#       dtype=object)

# %%
df['QUALIFIED'].unique()
# Out:
# array(['Q', 'U'], dtype=object)

# %%
df['STRUCT'].unique()
# Out:
# array(['Row Inside', 'Semi-Detached', 'Single', 'Row End', 'Multi',
#        'Town Inside', 'Town End', 'Default'], dtype=object)

# %%
df['GRADE'].unique()
# Out:
# array(['Very Good', 'Above Average', 'Good Quality', 'Excellent',
#        'Average', 'Superior', 'Fair Quality', 'Exceptional-C',
#        'Exceptional-A', 'Exceptional-B', 'Exceptional-D', 'No Data'],
#       dtype=object)

# %%
df['CNDTN'].unique()
# Out:
# array(['Good', 'Very Good', 'Average', 'Excellent', 'Fair', 'Poor',
#        'Default'], dtype=object)

# %%
df['EXTWALL'].unique()
# Out:
# array(['Common Brick', 'Stucco', 'Stone', 'Stucco Block', 'Brick/Stone',
#        'Concrete Block', 'Wood Siding', 'Brick/Siding', 'Face Brick',
#        'Brick/Stucco', 'Stone Veneer', 'Vinyl Siding', 'Stone/Stucco',
#        'Brick Veneer', 'Aluminum', 'Shingle', 'Metal Siding', 'Hardboard',
#        'Concrete', 'Default', 'Stone/Siding', 'Plywood'], dtype=object)

# %%
df['ROOF'].unique()
# Out:
# array(['Metal- Sms', 'Built Up', 'Neopren', 'Metal- Cpr', 'Slate',
#        'Comp Shingle', 'Metal- Pre', 'Shingle', 'Composition Ro', 'Shake',
#        'Typical', 'Water Proof', 'Clay Tile', 'Wood- FS'], dtype=object)

# %%
df['INTWALL'].unique()
# Out:
# array(['Hardwood', 'Wood Floor', 'Carpet', 'Hardwood/Carp',
#        'Ceramic Tile', 'Lt Concrete', 'Default', 'Parquet', 'Resiliant',
#        'Vinyl Sheet', 'Terrazo', 'Vinyl Comp'], dtype=object)

# %%
#df['SOURCE'].unique()
# Out:
# array(['Residential'], dtype=object)

# %%
#df['CITY'].unique()
# Out:
# array(['WASHINGTON'], dtype=object)

# %%
#df['NATIONALGRID'].unique()
# Out:
# array(['18S UJ 23061 09289', '18S UJ 23074 09289', '18S UJ 23078 09288',
#        ..., '18S UH 25851 98915', '18S UH 25807 98865',
#        '18S UH 25804 98859'], dtype=object)

# %%
#df['STATE'].unique()
# Out:
# array(['DC'], dtype=object)

# %%
df['ZIPCODE'].unique()
# Out:
# array([20009, 20036, 20005, 20008, 20001, 20024, 20003, 20002, 20007,
#        20016, 20015, 20010, 20011, 20012, 20017, 20018, 20019, 20020,
#        20032], dtype=int64)

# %%
#df['ASSESSMENT_NBHD'].unique()
# Out:
# array(['Old City 2', 'Old City 1', 'Capitol Hill', 'Georgetown',
#        'Burleith', 'Palisades', 'Berkley', 'Kent', 'Wesley Heights',
#        'American University', 'Spring Valley', 'Chevy Chase', 'Kalorama',
#        'Mt. Pleasant', 'Crestwood', 'Columbia Heights',
#        '16th Street Heights', 'Brightwood', 'Petworth', 'Ledroit Park',
#        'Eckington', 'Brookland', 'Brentwood', 'Trinidad', 'Woodridge',
#        'Lily Ponds', 'Deanwood', 'Marshall Heights', 'Fort Dupont Park',
#        'Hillcrest', 'Anacostia', 'Randle Heights', 'Congress Heights'],
#       dtype=object)

# %%
#df['ASSESSMENT_SUBNBHD'].nunique()
# Out:
# 120

# %%
#df['CENSUS_BLOCK'].nunique()
# Out:
# 3019

# %%
#df['WARD'].unique()
# Out:
# array(['Ward 2', 'Ward 1', 'Ward 6', 'Ward 5', 'Ward 3', 'Ward 4',
#        'Ward 7', 'Ward 8'], dtype=object)

# %%
df['QUADRANT'].unique()
# Out:
# array(['NW', 'SW', 'SE', 'NE'], dtype=object)

# %%
Q = pd.get_dummies(df['QUADRANT'],drop_first=True)
C = pd.get_dummies(df['CNDTN'],drop_first=True)
C.columns = ['CNDTN_1', 'CNDTN_1', 'CNDTN_3', 'CNDTN_4', 'CNDTN_5', 'CNDTN_6']
A = pd.get_dummies(df['AC'],drop_first=True)
A.columns=['AC_1','AC_2']
QU= pd.get_dummies(df['QUALIFIED'],drop_first=True)
Ext_wall = pd.get_dummies(df['EXTWALL'],drop_first=True)
Ext_wall.columns = ['Ext_wall1', 'Ext_wall2', 'Ext_wall3', 'Ext_wall4', 'Ext_wall5',
       'Ext_wall6', 'Ext_wall7', 'Ext_wall8', 'Ext_wall9',
       'Ext_wall10', 'Ext_wall11', 'Ext_wall12', 'Ext_wall13',
       'Ext_wall14', 'Ext_wall15', 'Ext_wall16', 'Ext_wall17', 'Ext_wall18',
       'Ext_wall19', 'Ext_wall20', 'Ext_wall21']
GR=pd.get_dummies(df['GRADE'],drop_first=True)
GR.columns=['Grade_1', 'Grade_2', 'Grade_3', 'Grade_4',
       'Grade_5', 'Grade_6', 'Grade_7', 'Grade_8',
       'Grade_9', 'Grade_10', 'Grade_11']
STYLE = pd.get_dummies(df['STYLE'],drop_first=True)
STYLE.columns = ['Style_1', 'Style_2', 'Style_3', 'Style_4', 'Style_5',
       'Style_6', 'Style_7', 'Style_8', 'Style_9',
       'Style_10', 'Style_11', 'Style_12', 'Style_13',
       'Style_14', 'Style_15', 'Style_16']

# %%
df = pd.concat([df,Q,C,A,QU,INT_WALL,R_F,S_T,H_T,Ext_wall,GR,STYLE],axis=1)

# %%
INT_WALL=pd.get_dummies(df['INTWALL'],drop_first=True)
R_F = pd.get_dummies(df['ROOF'],drop_first=True)
S_T = pd.get_dummies(df['STRUCT'],drop_first=True)
S_T.columns=['STRUCT_1', 'STRUCT_2', 'STRUCT_3', 'STRUCT_4', 'STRUCT_5',
       'STRUCT_6', 'STRUCT_7']
H_T = pd.get_dummies(df['HEAT'],drop_first=True)

# %%
df.drop(labels=['KITCHENS','CNDTN','QUADRANT','FULLADDRESS','QUALIFIED','USECODE','SALEDATE','GIS_LAST_MOD_DTTM','X','AC','HEAT','WARD','CENSUS_BLOCK','ASSESSMENT_SUBNBHD', 'ASSESSMENT_NBHD','STATE','NATIONALGRID','CITY','SOURCE','INTWALL','ROOF','EXTWALL','GRADE','STRUCT','CENSUS_TRACT','STYLE','AC','HEAT', 'LATITUDE'],inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['BATHRM', 'HF_BATHRM', 'NUM_UNITS', 'ROOMS', 'BEDRM', 'AYB', 'YR_RMDL',
#        'EYB', 'STORIES', 'PRICE',
#        ...
#        'Style_7', 'Style_8', 'Style_9', 'Style_10', 'Style_11', 'Style_12',
#        'Style_13', 'Style_14', 'Style_15', 'Style_16'],
#       dtype='object', length=179)

# %%
sns.heatmap(data = df.corr(),annot= True)

# %%
imp_features = df[['BATHRM','EYB','GBA','FIREPLACES']]

# %%
#df.drop(labels = ['X', 'LATITUDE'], inplace = True,axis=1)

# %%
sns.heatmap(df.corr(),xticklabels=df.columns,yticklabels=df.columns)
sns.set(rc={'figure.figsize':(30,30)})
fig=plt.figure(figsize=(30,30))
ax=fig.add_subplot()
ax.matshow(df.corr(),cmap=plt.cm.RdYlGn)
ax.set_xticks(np.arange(len(df.columns)))
ax.set_yticks(np.arange(len(df.columns)))
ax.set_xticklabels(df.columns)
ax.set_yticklabels(df.columns)
plt.show()

# %%
Y = df['PRICE']
X = df.drop(labels=['PRICE'],axis = 1)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,train_size = 0.25,random_state = 14)
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
#X_train= scaler.fit_transform(X_train)
#X_test = scaler.fit_transform(X_test)
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()
model1.fit(X_train,y_train)
predictions = model1.predict(X_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score
print('MODEL Linear Regressioon')
print('MAE : ',mean_absolute_error(y_test,predictions))
print('MSE : ',mean_squared_error(y_test,predictions)) 
print('RMSE : ',np.sqrt(mean_squared_error(y_test,predictions)))
print('R^2 : ',explained_variance_score(y_test,predictions))
# Out:
# MODEL Linear Regressioon
# MAE :  191522.72532870198
# MSE :  103977710115.48273
# RMSE :  322455.74908114556
# R^2 :  0.7084608620379128

# %%
from sklearn.linear_model import ElasticNet,Lasso, Ridge

model2 = ElasticNet()


model2.fit(X_train,y_train)
predictions_2 = model2.predict(X_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score
print("MODEL ElasticNet")
print('MAE : ',mean_absolute_error(y_test,predictions_2))
print('MSE : ',mean_squared_error(y_test,predictions_2)) 
print('RMSE : ',np.sqrt(mean_squared_error(y_test,predictions_2)))
print('R^2 : ',explained_variance_score(y_test,predictions_2))
# Out:
# MODEL ElasticNet
# MAE :  220462.35839335274
# MSE :  136823522976.8501
# RMSE :  369896.63823404786
# R^2 :  0.6163985616050143

# %%
model3 = Lasso(max_iter=100000)
model3.fit(X_train,y_train)
predictions_3 = model3.predict(X_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score
print("MODEL Lasso Regression")
print('MAE : ',mean_absolute_error(y_test,predictions_3))
print('MSE : ',mean_squared_error(y_test,predictions_3)) 
print('RMSE : ',np.sqrt(mean_squared_error(y_test,predictions_3)))
print('R^2 : ',explained_variance_score(y_test,predictions_3))
# Out:
# MODEL Lasso Regression
# MAE :  191508.36798048546
# MSE :  103955729233.90205
# RMSE :  322421.6637167888
# R^2 :  0.7085225835186966

# %%
model4 = Ridge()
model4.fit(X_train,y_train)
predictions_4 = model4.predict(X_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score
print("MODEL Ridge Regression")
print('MAE : ',mean_absolute_error(y_test,predictions_4))
print('MSE : ',mean_squared_error(y_test,predictions_4)) 
print('RMSE : ',np.sqrt(mean_squared_error(y_test,predictions_4)))
print('R^2 : ',explained_variance_score(y_test,predictions_4))
# Out:
# MODEL Ridge Regression
# MAE :  193014.0835718465
# MSE :  103459320521.16026
# RMSE :  321650.92961339356
# R^2 :  0.7099160942069

# %%
df.columns
# Out:
# Index(['BATHRM', 'HF_BATHRM', 'NUM_UNITS', 'ROOMS', 'BEDRM', 'AYB', 'YR_RMDL',
#        'EYB', 'STORIES', 'PRICE', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'FIREPLACES',
#        'LANDAREA', 'ZIPCODE', 'LONGITUDE', 'SQUARE', 'Y', 'NW', 'SE', 'SW',
#        'CNDTN_1', 'CNDTN_1', 'CNDTN_3', 'CNDTN_4', 'CNDTN_5', 'CNDTN_6',
#        'AC_1', 'AC_2', 'U', 'Ceramic Tile', 'Default', 'Hardwood',
#        'Hardwood/Carp', 'Lt Concrete', 'Parquet', 'Resiliant', 'Terrazo',
#        'Vinyl Comp', 'Vinyl Sheet', 'Wood Floor', 'Clay Tile', 'Comp Shingle',
#        'Composition Ro', 'Metal- Cpr', 'Metal- Pre', 'Metal- Sms', 'Neopren',
#        'Shake', 'Shingle', 'Slate', 'Typical', 'Water Proof', 'Wood- FS',
#        'STRUCT_1', 'STRUCT_2', 'STRUCT_3', 'STRUCT_4', 'STRUCT_5', 'STRUCT_6',
#        'STRUCT_7', 'Air-Oil', 'Elec Base Brd', 'Electric Rad', 'Evp Cool',
#        'Forced Air', 'Gravity Furnac', 'Hot Water Rad', 'Ht Pump', 'Ind Unit',
# ...

# %%
model1.coef_
# Out:
# array([ 5.04020017e+04,  2.28006078e+04, -6.31560958e+04, -8.83652631e+03,
#         4.77487364e+03, -4.11787527e+03,  1.47179379e+03,  1.02479429e+04,
#         1.33831300e+02,  5.74426530e+04,  1.71095683e+02, -2.46187586e+17,
#         8.77378402e+04,  8.55789883e+01, -2.47306952e+03, -9.45709214e+05,
#        -3.83553103e+01, -3.04575695e+06,  6.36310504e+04, -8.25483137e+04,
#        -2.44822765e+05,  1.70398902e+17,  6.44057022e+05,  1.41547680e+05,
#         5.41351002e+04, -1.46109131e+04,  2.26879637e+05,  7.79731689e+17,
#         7.79731689e+17, -1.65152226e+05, -8.07244420e+04, -4.84527022e+04,
#         2.10422057e+02, -5.93797038e+04, -6.07497342e+02, -8.23180900e+13,
#        -1.16872957e+05,  1.01880292e+06, -5.44345825e+12,  1.55406114e+12,
#        -1.33497067e+04, -2.21644157e+05, -5.10267750e+04, -8.93204288e+04,
#         2.35845095e+05,  7.36263460e+04, -1.37239131e+04, -3.34366199e+04,
# ...

# %%
print(model1.intercept_)
# Out:
# -8.767147838413184e+17

# %%
pd.DataFrame(model1.coef_,X.columns,columns=['Coeff'])
# Out:
#                        Coeff
# BATHRM          5.918080e+04
# HF_BATHRM       5.537209e+03
# NUM_UNITS      -6.215729e+04
# ROOMS          -6.124239e+03
# BEDRM          -7.363194e+03
# AYB            -1.970661e+03
# YR_RMDL         6.957333e+02
# EYB             8.279935e+03
# STORIES         1.133952e+03
# SALE_NUM        5.975647e+04
# GBA             2.429419e+02
# BLDG_NUM       -3.066743e-06
# FIREPLACES      7.777139e+04
# LANDAREA        2.913092e+01
# ZIPCODE        -1.435483e+03
# LONGITUDE      -1.342558e+06
# SQUARE         -3.815922e+01
# Y              -2.917755e+06
# NW              5.004717e+04
# SE             -8.755641e+04
# SW             -2.023246e+05
# Default         4.307367e-09
# Excellent       7.376004e+05
# Fair            1.789811e+04
# Good            4.872426e+04
# Poor           -3.214978e+05
# Very Good       2.462536e+05
# AC_N            1.933251e+04
# AC_Y            8.216934e+03
# U              -1.220829e+05
# ...                      ...
# ...

# %%
predictions
# Out:
# array([1564288.,  704768., -120320., ...,  -24576.,  341120.,  207104.])

# %%
plt.scatter(y_test, predictions)
plt.xlabel('y_test (true values)')
plt.ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %%
plt.scatter(y_test, predictions_2)
plt.xlabel('y_test (true values)')
plt.ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %%
plt.scatter(y_test, predictions_3)
plt.xlabel('y_test (true values)')
plt.ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %%
plt.scatter(y_test, predictions_4)
plt.xlabel('y_test (true values)')
plt.ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %%
sns.distplot(y_test-predictions)

# %%
# Out:
# MAE :  356950799513692.9
# MSE :  2.583195714984663e+32
# RMSE :  1.6072323151880262e+16
# R^2 :  -7.251228099605293e+20

# %%
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(imp_features,Y,train_size = 0.10)
from sklearn.linear_model import LinearRegression
model2 = LinearRegression(normalize=True)
model2.fit(X_train1,y_train1)
predictions1 = model2.predict(X_test1)
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score
print("MODEL LR with Top 5 correlated features")
print('MAE : ',mean_absolute_error(y_test1,predictions1))
print('MSE : ',mean_squared_error(y_test1,predictions1)) 
print('RMSE : ',np.sqrt(mean_squared_error(y_test1,predictions1)))
print('R^2 : ',explained_variance_score(y_test1,predictions1))
# Out:
# MODEL LR with Top 5 correlated features
# MAE :  256113.79095611896
# MSE :  182811593748.35706
# RMSE :  427564.72463050205
# R^2 :  0.4985139117491617
